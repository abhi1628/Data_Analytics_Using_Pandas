# %%
import pandas as pd

# %%
data = pd.read_csv('https://bit.ly/drinksbycountry')
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
data.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %%
data.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
data.shape
# Out:
# (193, 6)

# %%
data.size
# Out:
# 1158

# %%
data.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# ## Reading single column

# %%
data.country # using dot convention
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 188      Venezuela
# 189        Vietnam
# 190          Yemen
# 191         Zambia
# 192       Zimbabwe
# Name: country, Length: 193, dtype: object

# %%
data.spirit_servings
# Out:
# 0        0
# 1      132
# 2        0
# 3      138
# 4       57
#       ...
# 188    100
# 189      2
# 190      0
# 191     19
# 192     18
# Name: spirit_servings, Length: 193, dtype: int64

# %%
data['spirit_servings'] # using bracket notation
# Out:
# 0        0
# 1      132
# 2        0
# 3      138
# 4       57
#       ...
# 188    100
# 189      2
# 190      0
# 191     19
# 192     18
# Name: spirit_servings, Length: 193, dtype: int64

# %% [markdown]
# ## Adding new column in dataset

# %%
data['location'] = data.country + ',' + data.continent

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent          location
# 0                           0.0      Asia  Afghanistan,Asia
# 1                           4.9    Europe    Albania,Europe
# 2                           0.7    Africa    Algeria,Africa
# 3                          12.4    Europe    Andorra,Europe
# 4                           5.9    Africa     Angola,Africa

# %% [markdown]
# ## Rename columns

# %%
data.rename(columns={'total_litres_of_pure_alcohol':'total',
                    'beer_servings':'beer', 
                    'spirit_servings':'spirit',
                    'wine_servings':'wine'}, inplace = True)
data.head()
# Out:
#        country  beer  spirit  wine  total continent          location
# 0  Afghanistan     0       0     0    0.0      Asia  Afghanistan,Asia
# 1      Albania    89     132    54    4.9    Europe    Albania,Europe
# 2      Algeria    25       0    14    0.7    Africa    Algeria,Africa
# 3      Andorra   245     138   312   12.4    Europe    Andorra,Europe
# 4       Angola   217      57    45    5.9    Africa     Angola,Africa

# %% [markdown]
# ## Removing a column

# %%
data.drop('country', axis = 1, inplace = True)
data.head()
# Out:
#    beer  spirit  wine  total continent          location
# 0     0       0     0    0.0      Asia  Afghanistan,Asia
# 1    89     132    54    4.9    Europe    Albania,Europe
# 2    25       0    14    0.7    Africa    Algeria,Africa
# 3   245     138   312   12.4    Europe    Andorra,Europe
# 4   217      57    45    5.9    Africa     Angola,Africa

# %% [markdown]
# ## Removing multiple columns

# %%
data = pd.read_csv('https://bit.ly/drinksbycountry')
data.rename(columns={'total_litres_of_pure_alcohol':'total',
                    'beer_servings':'beer', 
                    'spirit_servings':'spirit',
                    'wine_servings':'wine'}, inplace = True)
data.head()
# Out:
#        country  beer  spirit  wine  total continent
# 0  Afghanistan     0       0     0    0.0      Asia
# 1      Albania    89     132    54    4.9    Europe
# 2      Algeria    25       0    14    0.7    Africa
# 3      Andorra   245     138   312   12.4    Europe
# 4       Angola   217      57    45    5.9    Africa

# %%
data['location'] = data.country + ',' + data.continent

# %%
data.head()
# Out:
#        country  beer  spirit  wine  total continent          location
# 0  Afghanistan     0       0     0    0.0      Asia  Afghanistan,Asia
# 1      Albania    89     132    54    4.9    Europe    Albania,Europe
# 2      Algeria    25       0    14    0.7    Africa    Algeria,Africa
# 3      Andorra   245     138   312   12.4    Europe    Andorra,Europe
# 4       Angola   217      57    45    5.9    Africa     Angola,Africa

# %%
data.drop(['country', 'continent'], axis = 1, inplace = True)
data.head()
# Out:
#    beer  spirit  wine  total          location
# 0     0       0     0    0.0  Afghanistan,Asia
# 1    89     132    54    4.9    Albania,Europe
# 2    25       0    14    0.7    Algeria,Africa
# 3   245     138   312   12.4    Andorra,Europe
# 4   217      57    45    5.9     Angola,Africa
